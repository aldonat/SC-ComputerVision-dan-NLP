# %% [markdown]
# <a href="https://colab.research.google.com/github/aldonat/SC-ComputerVision-dan-NLP/blob/main/FasterRCNN_Object_Detection_Aquarium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection with Faster RCNN
#
# Code is for the following video: https://www.youtube.com/watch?v=Uc90rr5jbA4&t=71s
#
# Do give this notebook a thumbs-up if you liked it. Thanks!

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %% [markdown]
# We require the latest version of torchvision

# %%
# !pip install -U torchvision # We need a new versino of torchvision for this project
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)

# %% [markdown]
# Here are all the necessary libraries

# %%
import torch
import torchvision
from torchvision import datasets, models
from torchvision.transforms import functional as FT
from torchvision import transforms as T
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, sampler, random_split, Dataset
import copy
import math
from PIL import Image
import cv2
import albumentations as A  # our data augmentation library

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# remove arnings (optional)
import warnings
warnings.filterwarnings("ignore")
from collections import defaultdict, deque
import datetime
import time
from tqdm import tqdm # progress bar
from torchvision.utils import draw_bounding_boxes

# %%
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.5.1+cu124
# 0.20.1+cu124

# %% [markdown]
# PyCOCOTools provides many utilities for dealing with datasets in the COCO format, and if you wanted, you could evaluate the model's performance on the dataset with some of the utilities provided with this library.
#
# That is out of scope for this notebook, however.

# %%
# our dataset is in cocoformat, we will need pypcoco tools
# !pip install pycocotools
from pycocotools.coco import COCO
# Out:
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
# Now, we will define our transforms
from albumentations.pytorch import ToTensorV2

# %% [markdown]
# We use albumentations as our data augmentation library due to its capability to deal with bounding boxes in multiple formats

# %%
def get_transforms(train=False):
    if train:
        transform = A.Compose([
            A.Resize(600, 600), # our input size can be 600px
            A.HorizontalFlip(p=0.3),
            A.VerticalFlip(p=0.3),
            A.RandomBrightnessContrast(p=0.1),
            A.ColorJitter(p=0.1),
            ToTensorV2()
        ], bbox_params=A.BboxParams(format='coco'))
    else:
        transform = A.Compose([
            A.Resize(600, 600), # our input size can be 600px
            ToTensorV2()
        ], bbox_params=A.BboxParams(format='coco'))
    return transform

# %% [markdown]
# ## Dataset
#
# This is our dataset class. It loads all the necessary files and it processes the data so that it can be fed into the model.

# %%
class AquariumDetection(datasets.VisionDataset):
    def __init__(self, root, split='train', transform=None, target_transform=None, transforms=None):
        # the 3 transform parameters are reuqired for datasets.VisionDataset
        super().__init__(root, transforms, transform, target_transform)
        self.split = split #train, valid, test
        self.coco = COCO(os.path.join(root, split, "_annotations.coco.json")) # annotatiosn stored here
        self.ids = list(sorted(self.coco.imgs.keys()))
        self.ids = [id for id in self.ids if (len(self._load_target(id)) > 0)]

    def _load_image(self, id: int):
        path = self.coco.loadImgs(id)[0]['file_name']
        image = cv2.imread(os.path.join(self.root, self.split, path))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        return image
    def _load_target(self, id):
        return self.coco.loadAnns(self.coco.getAnnIds(id))

    def __getitem__(self, index):
        id = self.ids[index]
        image = self._load_image(id)
        target = self._load_target(id)
        target = copy.deepcopy(self._load_target(id))

        boxes = [t['bbox'] + [t['category_id']] for t in target] # required annotation format for albumentations
        if self.transforms is not None:
            transformed = self.transforms(image=image, bboxes=boxes)

        image = transformed['image']
        boxes = transformed['bboxes']

        new_boxes = [] # convert from xywh to xyxy
        for box in boxes:
            xmin = box[0]
            xmax = xmin + box[2]
            ymin = box[1]
            ymax = ymin + box[3]
            new_boxes.append([xmin, ymin, xmax, ymax])

        boxes = torch.tensor(new_boxes, dtype=torch.float32)

        targ = {} # here is our transformed target
        targ['boxes'] = boxes
        targ['labels'] = torch.tensor([t['category_id'] for t in target], dtype=torch.int64)
        targ['image_id'] = torch.tensor([t['image_id'] for t in target])
        targ['area'] = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0]) # we have a different area
        targ['iscrowd'] = torch.tensor([t['iscrowd'] for t in target], dtype=torch.int64)
        return image.div(255), targ # scale images
    def __len__(self):
        return len(self.ids)

# %%
# !kaggle datasets download sharansmenon/aquarium-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sharansmenon/aquarium-dataset
# License(s): copyright-authors
# aquarium-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip aquarium-dataset.zip
# Out:
# Archive:  aquarium-dataset.zip
#   inflating: Aquarium Combined/README.dataset.txt
#   inflating: Aquarium Combined/README.roboflow.txt
#   inflating: Aquarium Combined/test/IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg
#   inflating: Aquarium Combined/test/IMG_2301_jpeg_jpg.rf.2c19ae5efbd1f8611b5578125f001695.jpg
#   inflating: Aquarium Combined/test/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg
#   inflating: Aquarium Combined/test/IMG_2347_jpeg_jpg.rf.7c71ac4b9301eb358cd4a832844dedcb.jpg
#   inflating: Aquarium Combined/test/IMG_2354_jpeg_jpg.rf.396e872c7fb0a95e911806986995ee7a.jpg
#   inflating: Aquarium Combined/test/IMG_2371_jpeg_jpg.rf.54505f60b6706da151c164188c305849.jpg
#   inflating: Aquarium Combined/test/IMG_2379_jpeg_jpg.rf.7dc3160c937072d26d4624c6c48e904d.jpg
#   inflating: Aquarium Combined/test/IMG_2380_jpeg_jpg.rf.a23809682eb1466c1136ca0f55de8fb5.jpg
#   inflating: Aquarium Combined/test/IMG_2387_jpeg_jpg.rf.09b38bacfab0922a3a6b66480f01b719.jpg
#   inflating: Aquarium Combined/test/IMG_2395_jpeg_jpg.rf.9f1503ad3b7a7c7938daed057cc4e9bc.jpg
#   inflating: Aquarium Combined/test/IMG_2423_jpeg_jpg.rf.1c0901882e71d5ebd26f036f4e22da65.jpg
#   inflating: Aquarium Combined/test/IMG_2434_jpeg_jpg.rf.8b20d3270d4fbc497c64125273f46ecb.jpg
#   inflating: Aquarium Combined/test/IMG_2446_jpeg_jpg.rf.06ee05e92df8e3c33073147d8f595211.jpg
#   inflating: Aquarium Combined/test/IMG_2448_jpeg_jpg.rf.28ce79dab47ad525751d5407be09bc3d.jpg
#   inflating: Aquarium Combined/test/IMG_2450_jpeg_jpg.rf.ff673921373de3bfc275863e3befeefe.jpg
#   inflating: Aquarium Combined/test/IMG_2465_jpeg_jpg.rf.7e699ec1d2e373d93dac32cd02db9438.jpg
#   inflating: Aquarium Combined/test/IMG_2466_jpeg_jpg.rf.53886abb9947ec4e47405957b30fe314.jpg
#   inflating: Aquarium Combined/test/IMG_2468_jpeg_jpg.rf.c933cc14c99b11a90413a1490d4556db.jpg
#   inflating: Aquarium Combined/test/IMG_2470_jpeg_jpg.rf.75b359c8baa6866bfecf07a0e4e8c33d.jpg
#   inflating: Aquarium Combined/test/IMG_2473_jpeg_jpg.rf.6284677f9c781b0cfeec54981a17d573.jpg
#   inflating: Aquarium Combined/test/IMG_2477_jpeg_jpg.rf.7b2692f142d53c16ad477065f1f8ae6d.jpg
#   inflating: Aquarium Combined/test/IMG_2496_jpeg_jpg.rf.3f91e7f18502074c89fa720a11926fab.jpg
#   inflating: Aquarium Combined/test/IMG_2499_jpeg_jpg.rf.6cbab3719b9063388b5ab3ab826d7bd3.jpg
#   inflating: Aquarium Combined/test/IMG_2514_jpeg_jpg.rf.6ccb3859d75fc5cfe053b1c1474254b2.jpg
#   inflating: Aquarium Combined/test/IMG_2526_jpeg_jpg.rf.003e1d1d41bcd204df731b85cea68781.jpg
#   inflating: Aquarium Combined/test/IMG_2532_jpeg_jpg.rf.2afeb76e5d9372dbbd6fbc53d5b75675.jpg
#   inflating: Aquarium Combined/test/IMG_2544_jpeg_jpg.rf.03f51bb9e1c57fb9cd62f8cbdca14e90.jpg
#   inflating: Aquarium Combined/test/IMG_2547_jpeg_jpg.rf.9406b6f1a9fad2292c4abd28f712baaf.jpg
#   inflating: Aquarium Combined/test/IMG_2570_jpeg_jpg.rf.ed40900b657a5b23d92cb2d296ad2dbc.jpg
#   inflating: Aquarium Combined/test/IMG_2574_jpeg_jpg.rf.ca0c3ad32384309a61e92d9a8bef87b9.jpg
#   inflating: Aquarium Combined/test/IMG_2582_jpeg_jpg.rf.14f175066ce74b470bf31fa0c7a096cd.jpg
#   inflating: Aquarium Combined/test/IMG_2588_jpeg_jpg.rf.cb9cea8f05891cfd55a3e93f2908201f.jpg
#   inflating: Aquarium Combined/test/IMG_2630_jpeg_jpg.rf.310f0c986a72be46b80ce31c2d00e46d.jpg
#   inflating: Aquarium Combined/test/IMG_2632_jpeg_jpg.rf.f44037edca490b16cbf06427e28ea946.jpg
#   inflating: Aquarium Combined/test/IMG_2651_jpeg_jpg.rf.84b3930aa80b610cc97bf1c176763940.jpg
#   inflating: Aquarium Combined/test/IMG_3129_jpeg_jpg.rf.90c472dcdf9b6713ec767cc97560ceca.jpg
#   inflating: Aquarium Combined/test/IMG_3134_jpeg_jpg.rf.50750ca778773042a3c46a1d3e480132.jpg
#   inflating: Aquarium Combined/test/IMG_3136_jpeg_jpg.rf.0d8fef73d4cc5e1c35ce424444d9e44b.jpg
#   inflating: Aquarium Combined/test/IMG_3144_jpeg_jpg.rf.f29a36360174dc83ecef93275ed8f02e.jpg
#   inflating: Aquarium Combined/test/IMG_3154_jpeg_jpg.rf.5f429a366c02d38bc9e2217f4508c3e0.jpg
#   inflating: Aquarium Combined/test/IMG_3164_jpeg_jpg.rf.06637eee0b72df791aa729807ca45c4d.jpg
#   inflating: Aquarium Combined/test/IMG_3173_jpeg_jpg.rf.6f05acaa0b22d410a5df3ea3286e227d.jpg
#   inflating: Aquarium Combined/test/IMG_3175_jpeg_jpg.rf.686c7d36e049eea974a363e99bf0bee0.jpg
#   inflating: Aquarium Combined/test/IMG_8331_jpg.rf.ec024bdf1e9de02b020b5e6505c1c58b.jpg
#   inflating: Aquarium Combined/test/IMG_8343_jpg.rf.2d88000497d74d72aedc118b125a0c07.jpg
#   inflating: Aquarium Combined/test/IMG_8395_jpg.rf.3bebece033961c9f665571644a14261f.jpg
#   inflating: Aquarium Combined/test/IMG_8396_jpg.rf.106a6ced5c649ea81f0de8ecaa4ff3b8.jpg
#   inflating: Aquarium Combined/test/IMG_8404_jpg.rf.265b89e862a375f6b89f781ea60ed480.jpg
#   inflating: Aquarium Combined/test/IMG_8420_jpg.rf.31f1d5f1440e48ccf1dee988b565911b.jpg
#   inflating: Aquarium Combined/test/IMG_8452_jpg.rf.6bbff701ab93e29553b3a70137fd4e66.jpg
#   inflating: Aquarium Combined/test/IMG_8490_jpg.rf.1836542cf054c6d303a2dd05d4194d7f.jpg
#   inflating: Aquarium Combined/test/IMG_8497_MOV-0_jpg.rf.5c59bd1bf7d8fd7a20999d51a79a12c0.jpg
#   inflating: Aquarium Combined/test/IMG_8497_MOV-3_jpg.rf.fd813e14681c8b41e709a500748ce46a.jpg
#   inflating: Aquarium Combined/test/IMG_8497_MOV-5_jpg.rf.3deffb208d656b7845661c5e33dd1afb.jpg
#   inflating: Aquarium Combined/test/IMG_8513_MOV-0_jpg.rf.2a2f77e3f73630b60aaf6ad3ca4ed130.jpg
#   inflating: Aquarium Combined/test/IMG_8515_jpg.rf.98a9daca7c5a5bad9872bd7fb2d4f198.jpg
#   inflating: Aquarium Combined/test/IMG_8582_MOV-0_jpg.rf.aa8304d7a5112d63c8841d96160d42cd.jpg
#   inflating: Aquarium Combined/test/IMG_8582_MOV-3_jpg.rf.c7dde0639837077f76428d70223368a4.jpg
#   inflating: Aquarium Combined/test/IMG_8582_MOV-5_jpg.rf.9d7a26fbf145ce39ab0831b4e6bc1f1e.jpg
#   inflating: Aquarium Combined/test/IMG_8590_MOV-2_jpg.rf.2136fdb5dcbcd58a1dc456bb3e5bf476.jpg
#   inflating: Aquarium Combined/test/IMG_8590_MOV-5_jpg.rf.074e6d8acdd3fcad16d866c341b43769.jpg
#   inflating: Aquarium Combined/test/IMG_8595_MOV-0_jpg.rf.312ab0b8b9fca18134aee88044f45a06.jpg
#   inflating: Aquarium Combined/test/IMG_8599_MOV-3_jpg.rf.412ebb16ea80e964b4464c50e757df0e.jpg
#   inflating: Aquarium Combined/test/_annotations.coco.json
#   inflating: Aquarium Combined/train/.ipynb_checkpoints/IMG_2274_jpeg_jpg.rf.2f319e949748145fb22dcb52bb325a0c-checkpoint.jpg
#   inflating: Aquarium Combined/train/.ipynb_checkpoints/IMG_
#   inflating: Aquarium Combined/valid/IMG_8525_jpg.rf.79694f37cc584fbeb7ff0cc0e19427a2.jpg
#   inflating: Aquarium Combined/valid/IMG_8526_jpg.rf.f371583278d1a5bb0d9352efe689fc33.jpg
#   inflating: Aquarium Combined/valid/IMG_8528_jpg.rf.2b4f4faa5412fc350cc967990c6249c5.jpg
#   inflating: Aquarium Combined/valid/IMG_8530_jpg.rf.a4abb3dc30e6984d6dd52f96b9f654f9.jpg
#   inflating: Aquarium Combined/valid/IMG_8535_MOV-0_jpg.rf.bb8a782b58745c0c8a6b334ab75a6b4c.jpg
#   inflating: Aquarium Combined/valid/IMG_8535_MOV-1_jpg.rf.1c1aa55d7b35e08b6760c9cc43d427d0.jpg
#   inflating: Aquarium Combined/valid/IMG_8535_MOV-4_jpg.rf.62f0b5fc7765e5f9015a7c0281bd969a.jpg
#   inflating: Aquarium Combined/valid/IMG_8535_MOV-5_jpg.rf.fe45012859267d87836726ec3fd4098f.jpg
#   inflating: Aquarium Combined/valid/IMG_8551_MOV-1_jpg.rf.c5ec93fd2bf5fd05d5efd9d3798fec83.jpg
#   inflating: Aquarium Combined/valid/IMG_8571_MOV-3_jpg.rf.dcfbae1a6996c6208f63e848e7947ec4.jpg
#   inflating: Aquarium Combined/valid/IMG_8572_MOV-1_jpg.rf.1c182e819e3efef65b32f7ef780942f8.jpg
#   inflating: Aquarium Combined/valid/IMG_8578_MOV-0_jpg.rf.259d80c0d67e3e88f2d04cd17df7f6a9.jpg
#   inflating: Aquarium Combined/valid/IMG_8579_jpg.rf.1c60d2b975a7e600c88ec25f38c5b13d.jpg
#   inflating: Aquarium Combined/valid/IMG_8581_MOV-1_jpg.rf.f5e474a5a6600f76112e98f60888d236.jpg
#   inflating: Aquarium Combined/valid/IMG_8582_MOV-2_jpg.rf.857b3cd92ca74b0f75e812a380dc5f22.jpg
#   inflating: Aquarium Combined/valid/IMG_8582_MOV-4_jpg.rf.3836024d5cae38ca6ba3512ee98ea3a3.jpg
#   inflating: Aquarium Combined/valid/IMG_8590_MOV-0_jpg.rf.0ffbdc8627360449c3b1d94adab945c4.jpg
#   inflating: Aquarium Combined/valid/IMG_8591_MOV-1_jpg.rf.a93070247a5bd3fae05926c0514b1b4c.jpg
#   inflating: Aquarium Combined/valid/IMG_8593_MOV-1_jpg.rf.9aa3076a6322416b5ce1c892d97a102a.jpg
#   inflating: Aquarium Combined/valid/IMG_8595_MOV-1_jpg.rf.7ec06740adf2a710a14c479f9bd8db5b.jpg
#   inflating: Aquarium Combined/valid/IMG_8599_MOV-1_jpg.rf.8b8f5d9d4eacd671546a3025e6f52a0e.jpg
#   inflating: Aquarium Combined/valid/_annotations.coco.json

# %%
dataset_path = "/content/Aquarium Combined"

# %%
#load classes
coco = COCO(os.path.join(dataset_path, "train", "_annotations.coco.json"))
categories = coco.cats
n_classes = len(categories.keys())
categories
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# {0: {'id': 0, 'name': 'creatures', 'supercategory': 'none'},
#  1: {'id': 1, 'name': 'fish', 'supercategory': 'creatures'},
#  2: {'id': 2, 'name': 'jellyfish', 'supercategory': 'creatures'},
#  3: {'id': 3, 'name': 'penguin', 'supercategory': 'creatures'},
#  4: {'id': 4, 'name': 'puffin', 'supercategory': 'creatures'},
#  5: {'id': 5, 'name': 'shark', 'supercategory': 'creatures'},
#  6: {'id': 6, 'name': 'starfish', 'supercategory': 'creatures'},
#  7: {'id': 7, 'name': 'stingray', 'supercategory': 'creatures'}}

# %% [markdown]
# This code just gets a list of classes

# %%
classes = [i[1]['name'] for i in categories.items()]
classes
# Out:
# ['creatures',
#  'fish',
#  'jellyfish',
#  'penguin',
#  'puffin',
#  'shark',
#  'starfish',
#  'stingray']

# %%
train_dataset = AquariumDetection(root=dataset_path, transforms=get_transforms(True))
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %% [markdown]
# This is a sample image and its bounding boxes, this code does not get the model's output

# %%
# Lets view a sample
sample = train_dataset[5]
img_int = torch.tensor(sample[0] * 255, dtype=torch.uint8)
plt.imshow(draw_bounding_boxes(
    img_int, sample[1]['boxes'], [classes[i] for i in sample[1]['labels']], width=4
).permute(1, 2, 0))

# %%
len(train_dataset)
# Out:
# 447

# %% [markdown]
# ## Model
#
# Our model is FasterRCNN with a backbone of `MobileNetV3-Large`. We need to change the output layers because we have just 7 classes but this model was trained on 90 classes.

# %%
# lets load the faster rcnn model
model = models.detection.fasterrcnn_mobilenet_v3_large_fpn(pretrained=True)
in_features = model.roi_heads.box_predictor.cls_score.in_features # we need to change the head
model.roi_heads.box_predictor = models.detection.faster_rcnn.FastRCNNPredictor(in_features, n_classes)

# %% [markdown]
# This is our collating function for the train dataloader, it allows us to create batches of data that can be easily pass into the model

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

# %%
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4, collate_fn=collate_fn)

# %% [markdown]
# The following blocks ensures that the model can take in the data and that it will not crash during training

# %%
images,targets = next(iter(train_loader))
images = list(image for image in images)
targets = [{k:v for k, v in t.items()} for t in targets]
output = model(images, targets) # just make sure this runs without error

# %%
device = torch.device("cuda") # use GPU to train

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")  # Use GPU if available
    print("Using CUDA device:", device)
else:
    device = torch.device("cpu")  # Fallback to CPU if CUDA is not available
    print("CUDA not available, using CPU device:", device)
# Out:
# Using CUDA device: cuda

# %%
model = model.to(device)

# %% [markdown]
# ## Optimizer
#
# Here, we define the optimizer. If you wish, you can also define the LR Scheduler, but it is not necessary for this notebook since our dataset is so small.
#
# > Note, there are a few bugs with the current way `lr_scheduler` is implemented. If you wish to use the scheduler, you will have to fix those bugs

# %%
# Now, and optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.01, momentum=0.9, nesterov=True, weight_decay=1e-4)
# lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[16, 22], gamma=0.1) # lr scheduler

# %%
import sys

# %% [markdown]
# ## Training
#
# The following is a function that will train the model for one epoch. Torchvision Object Detections models have a loss function built in, and it will calculate the loss automatically if you pass in the `inputs` and `targets`

# %%
def train_one_epoch(model, optimizer, loader, device, epoch):
    model.to(device)
    model.train()

#     lr_scheduler = None
#     if epoch == 0:
#         warmup_factor = 1.0 / 1000 # do lr warmup
#         warmup_iters = min(1000, len(loader) - 1)

#         lr_scheduler = optim.lr_scheduler.LinearLR(optimizer, start_factor = warmup_factor, total_iters=warmup_iters)

    all_losses = []
    all_losses_dict = []

    for images, targets in tqdm(loader):
        images = list(image.to(device) for image in images)
        targets = [{k: torch.tensor(v).to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets) # the model computes the loss automatically if we pass in targets
        losses = sum(loss for loss in loss_dict.values())
        loss_dict_append = {k: v.item() for k, v in loss_dict.items()}
        loss_value = losses.item()

        all_losses.append(loss_value)
        all_losses_dict.append(loss_dict_append)

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping trainig") # train if loss becomes infinity
            print(loss_dict)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

#         if lr_scheduler is not None:
#             lr_scheduler.step() #

    all_losses_dict = pd.DataFrame(all_losses_dict) # for printing
    print("Epoch {}, lr: {:.6f}, loss: {:.6f}, loss_classifier: {:.6f}, loss_box: {:.6f}, loss_rpn_box: {:.6f}, loss_object: {:.6f}".format(
        epoch, optimizer.param_groups[0]['lr'], np.mean(all_losses),
        all_losses_dict['loss_classifier'].mean(),
        all_losses_dict['loss_box_reg'].mean(),
        all_losses_dict['loss_rpn_box_reg'].mean(),
        all_losses_dict['loss_objectness'].mean()
    ))

# %% [markdown]
# 5 Epochs should be enough to train this model for a high accuracy

# %%
num_epochs=5

for epoch in range(num_epochs):
    train_one_epoch(model, optimizer, train_loader, device, epoch)
#     lr_scheduler.step()
# Out:
# 100%|██████████| 112/112 [00:22<00:00,  5.09it/s]
# Epoch 0, lr: 0.010000, loss: 0.998540, loss_classifier: 0.478252, loss_box: 0.392550, loss_rpn_box: 0.032064, loss_object: 0.095674
# 100%|██████████| 112/112 [00:19<00:00,  5.71it/s]
# Epoch 1, lr: 0.010000, loss: 0.780134, loss_classifier: 0.352724, loss_box: 0.335040, loss_rpn_box: 0.028953, loss_object: 0.063417
# 100%|██████████| 112/112 [00:19<00:00,  5.68it/s]
# Epoch 2, lr: 0.010000, loss: 0.714578, loss_classifier: 0.301569, loss_box: 0.339095, loss_rpn_box: 0.026272, loss_object: 0.047644
# 100%|██████████| 112/112 [00:21<00:00,  5.16it/s]
# Epoch 3, lr: 0.010000, loss: 0.687410, loss_classifier: 0.280669, loss_box: 0.339330, loss_rpn_box: 0.024795, loss_object: 0.042616
# 100%|██████████| 112/112 [00:19<00:00,  5.79it/s]
# Epoch 4, lr: 0.010000, loss: 0.670223, loss_classifier: 0.269998, loss_box: 0.338088, loss_rpn_box: 0.024135, loss_object: 0.038001

# %%
# our learning rate was too low, due to a lr scheduler bug. For this task, we wont need a scheudul.er

# %% [markdown]
# ## Trying on sample Images
#
# This is the inference code for the model. First, we set the model to evaluation mode and clear the GPU Cache. We also load a test dataset, so that we can use fresh images that the model hasn't seen.

# %%
# we will watch first epoich to ensure no errrors
# while it is training, lets write code to see the models predictions. lets try again
model.eval()
torch.cuda.empty_cache()

# %%
test_dataset = AquariumDetection(root=dataset_path, split="test", transforms=get_transforms(False))
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
img, _ = test_dataset[1]
img_int = torch.tensor(img*255, dtype=torch.uint8)
with torch.no_grad():
    prediction = model([img.to(device)])
    pred = prediction[0]

# %%
fig = plt.figure(figsize=(14, 10))
plt.imshow(draw_bounding_boxes(img_int,
    pred['boxes'][pred['scores'] > 0.8],
    [classes[i] for i in pred['labels'][pred['scores'] > 0.8].tolist()], width=4
).permute(1, 2, 0))

# %%
import pickle
filename = "model_1.pkl"
pickle.dump(model, open(filename, 'wb'))
